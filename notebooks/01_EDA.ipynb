# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("TensorFlow:", tf.__version__)
print("Pandas:", pd.__version__)

# %%
# Out:
# 20

# %%
import pandas as pd
from pathlib import Path

data=r"C:\Users\kumar\Skin_lesion_Classification\data\raw\ISIC2018"

paths = [path.parts[-2:] for path in
         Path(data).rglob('*.*')]                             #writing purpose ('*.*') so that all image formats can be retrieved
df = pd.DataFrame(data=paths, columns=['Class','Images'])     #create column names for dataframe
df = df.sort_values('Class',ascending=True)                   #sort class name
df.reset_index(drop=True, inplace=True)                       #sort index of each row
df
# Out:
#        Class            Images
# 0      AKIEC      aug_0_0.jpeg
# 1      AKIEC   aug_0_8432.jpeg
# 2      AKIEC    aug_0_843.jpeg
# 3      AKIEC   aug_0_8425.jpeg
# 4      AKIEC   aug_0_8416.jpeg
# ...      ...               ...
# 10883   VASC   aug_0_4103.jpeg
# 10884   VASC   aug_0_4099.jpeg
# 10885   VASC   aug_0_4094.jpeg
# 10886   VASC    aug_0_427.jpeg
# 10887   VASC  ISIC_0034214.jpg
#
# [10888 rows x 2 columns]

# %%
print('Count the number of image datasets')
print("Image Count : {}".format(len(df.Images)))
print("Class Count : {} \n".format(len(df['Class'].value_counts())))
print('Count the number of images in each class')
print(df['Class'].value_counts())
# Out:
# Count the number of image datasets
# Image Count : 10888
# Class Count : 7
#
# Count the number of images in each class
# Class
# DF       2195
# NV       2129
# VASC     2063
# AKIEC    1836
# MEL      1075
# BKL      1046
# BCC       544
# Name: count, dtype: int64

# %%
import seaborn as sns
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(15,9))
sns.countplot(data=df, x='Class')
plt.title('Graph of the count of each class')
plt.xlabel('\n Image Class')
plt.ylabel('Count Image')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Text(0, 0.5, 'Count Image')

# %%
Class_Id_Dist_Total = df['Class'].value_counts(sort=False)

import plotly.express as px
fig = px.pie(
    values=Class_Id_Dist_Total,
    names=Class_Id_Dist_Total.index,
    hole=0.5
)

fig.update_traces(textfont_size=15,textinfo='percent')
fig.show()

# %%
train_ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 train_ds
#
# NameError: name 'train_ds' is not defined
